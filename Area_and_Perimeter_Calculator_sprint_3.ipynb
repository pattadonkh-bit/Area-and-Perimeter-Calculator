# %% [markdown]
# <a href="https://colab.research.google.com/github/pattadonkh-bit/Area-and-Perimeter-Calculator/blob/main/Area_and_Perimeter_Calculator_sprint_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ✅ ความคาดหวังของครูใน Sprint 3
# 1. ความสมบูรณ์ของฟังก์ชัน (Functional Completeness)
#
# โปรแกรมต้องคำนวณพื้นที่และปริมาตร (เส้นรอบรูป) ของ สี่เหลี่ยมผืนผ้า, วงกลม, สี่เหลี่ยมจัตุรัส, และสามเหลี่ยม ได้ถูกต้อง
#
# โปรแกรมต้องจัดการกรณี ใส่ค่าผิดพลาด ได้ดี เช่น พิมพ์ตัวอักษรแทนตัวเลข หรือใส่ค่าติดลบ
#
# 2. คุณภาพและการจัดโครงสร้างโค้ด (Code Quality & Organization)
#
# โค้ดต้องอ่านง่าย ฟังก์ชันแยกชัดเจนตามหน้าที่
#
# ใช้ ชื่อตัวแปรและฟังก์ชันที่สื่อความหมาย
#
# ลดการเขียนโค้ดซ้ำ ถ้ามีส่วนที่เหมือนกันควรแยกออกเป็นฟังก์ชัน
#
# 3. การทำงานเป็นทีม (Teamwork & Roles)
#
#
# Planner: กำหนดความต้องการและสิ่งที่ต้องพัฒนาใน Sprint 3
#
# Coder: เขียนโค้ดตามแผน
#
# Debugger: ทดลองรัน ตรวจหาข้อผิดพลาด และแก้ไขร่วมกับ Coder
#
# 4. การทดสอบและการดีบัก (Testing & Debugging)
#
# ทดลองโปรแกรมด้วยข้อมูลหลายแบบ เช่น ค่าปกติ, ค่าศูนย์, ค่าติดลบ, ค่าขนาดใหญ่
#
# แก้ไขข้อผิดพลาดที่พบ และยืนยันว่าโปรแกรมไม่ล่ม
#
# 5. ประสบการณ์ผู้ใช้ (User Experience – UX)
#
# เมนูเลือกชัดเจน อ่านแล้วเข้าใจง่าย
#
# แสดงผลลัพธ์ชัดเจน เช่น “Rectangle Area = …”
#
# ถ้าใส่ค่าผิด ให้ข้อความเตือนที่เป็นมิตรและเข้าใจง่าย
#
# 🎯 How to Meet Those Expectations
# 📝 โอ่ง Planner
#
# เขียน เช็กลิสต์เป้าหมายของ Sprint 3 เช่น ปรับปรุง UX, เพิ่มการทดสอบ, จัดทำเอกสาร
#
# ตัดสินใจว่า ควรพัฒนาอะไรเพิ่มเติมจาก Sprint 2 (เช่น ตรวจสอบ input, เพิ่มรูปทรงใหม่)
#
# ประสานงานระหว่าง Coder และ Debugger ให้ทำงานสอดคล้องกัน
#
# 💻 โบ๊ท Coder
#
# ปรับโครงสร้างโค้ดให้สะอาดและอ่านง่ายขึ้น
#
# เพิ่ม ฟีเจอร์เล็ก ๆ เช่น การตรวจสอบ input หรือเพิ่มรูปทรงใหม่
#
# 🐞 โอ่ง Debugger
#
# ทดสอบแต่ละรูปทรงด้วยอย่างน้อย 3 ชุดข้อมูล
#
# ตรวจสอบว่าคำตอบที่ได้ ตรงกับการคำนวณด้วยมือ
#
# ทดลองกรณีที่อาจทำให้โปรแกรมพัง เช่น ใส่ตัวอักษรแทนตัวเลข หรือใส่ค่าติดลบ

# %%
import math

def rectangle_area(length, width):
    return length * width

def rectangle_perimeter(length, width):
    return 2 * (length + width)


def circle_area(radius):
    return math.pi * radius ** 2

def circle_perimeter(radius):
    return 2 * math.pi * radius


def square_area(side):
    return side ** 2

def square_perimeter(side):
    return 4 * side


def triangle_area(base, height):
    return 0.5 * base * height

def triangle_perimeter(a, b, c):
    return a + b + c


def parallelogram_area(base, height):
    return base * height

def parallelogram_perimeter(a, b):
    return 2 * (a + b)

def get_number(prompt):
    while True:
        value = input(prompt)
        try:
            num = float(value)
            if num > 0:
                return num
            else:
                print("Value must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")


if __name__ == "__main__":
    print("Area & Perimeter Calculator (Sprint 3)")

    while True:
        print("\nChoose shape:")
        print("1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit")
        choice = input("Enter choice (1-6): ")

        if choice == "1":
            l = get_number("Enter length: ")
            w = get_number("Enter width: ")
            print(f"Rectangle Area = {rectangle_area(l, w):.2f}")
            print(f"Rectangle Perimeter = {rectangle_perimeter(l, w):.2f}")

        elif choice == "2":
            r = get_number("Enter radius: ")
            print(f"Circle Area = {circle_area(r):.2f}")
            print(f"Circle Circumference = {circle_perimeter(r):.2f}")

        elif choice == "3":
            s = get_number("Enter side length: ")
            print(f"Square Area = {square_area(s):.2f}")
            print(f"Square Perimeter = {square_perimeter(s):.2f}")

        elif choice == "4":
            a = get_number("Enter side a: ")
            b = get_number("Enter side b: ")
            c = get_number("Enter side c: ")
            h = get_number("Enter height (for area): ")
            print(f"Triangle Area = {triangle_area(a, h):.2f}")
            print(f"Triangle Perimeter = {triangle_perimeter(a, b, c):.2f}")

        elif choice == "5":
            base = get_number("Enter base: ")
            height = get_number("Enter height: ")
            side_a = get_number("Enter side a: ")
            side_b = get_number("Enter side b: ")
            print(f"Parallelogram Area = {parallelogram_area(base, height):.2f}")
            print(f"Parallelogram Perimeter = {parallelogram_perimeter(side_a, side_b):.2f}")

        elif choice == "6":
            print("Exiting program. Goodbye!")
            break

        else:
            print("Invalid choice. Please select 1-6.")
# Out:
# Area & Perimeter Calculator (Sprint 3)
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 1'
# Invalid choice. Please select 1-6.
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 1
# Enter length: 5
# Enter width: 10
# Rectangle Area = 50.00
# Rectangle Perimeter = 30.00
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 2
# Enter radius: 7
# Circle Area = 153.94
# Circle Circumference = 43.98
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 3
# Enter side length: 6
# Square Area = 36.00
# Square Perimeter = 24.00
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 5
# Enter base: 8
# Enter height: 5
# Enter side a: 8
# Enter side b: 6
# ...

# %% [markdown]
# # **การเปลี่ยนแปลง**
#
# เพิ่มฟังก์ชันคำนวณพื้นที่และเส้นรอบรูป:

# %%
def parallelogram_area(base, height):
    return base * height

def parallelogram_perimeter(a, b):
    return 2 * (a + b)

# %% [markdown]
# เพิ่มตัวเลือกเมณู

# %%
5) Parallelogram

# %% [markdown]
# เพิ่มโค้ดรับค่าจากผู้ใช้สำหรับด้านและฐาน:

# %%
base = get_number("Enter base: ")
height = get_number("Enter height: ")
side_a = get_number("Enter side a: ")
side_b = get_number("Enter side b: ")

# %% [markdown]
# แสดงผลลัพธ์ของ parallelogram:

# %%
print(f"Parallelogram Area = {parallelogram_area(base, height):.2f}")
print(f"Parallelogram Perimeter = {parallelogram_perimeter(side_a, side_b):.2f}")

# %% [markdown]
# # **เนื่องจาก if-elif ยาวมากๆ จึงลองใช้ ใช้ Dictionary แทน**
#
# # **ตอนนี้โค้ดใช้ if choice == "1": ... elif choice == "2": ... ยาวมาก**

# %%
import math

# --- Geometry Functions ---
def rectangle_area(length, width): return length * width
def rectangle_perimeter(length, width): return 2 * (length + width)

def circle_area(radius): return math.pi * radius ** 2
def circle_perimeter(radius): return 2 * math.pi * radius

def square_area(side): return side ** 2
def square_perimeter(side): return 4 * side

def triangle_area(base, height): return 0.5 * base * height
def triangle_perimeter(a, b, c): return a + b + c

def parallelogram_area(base, height): return base * height
def parallelogram_perimeter(a, b): return 2 * (a + b)

# --- Input helper ---
def get_number(prompt):
    while True:
        try:
            value = float(input(prompt))
            if value > 0:
                return value
            else:
                print("Value must be greater than 0.")
        except ValueError:
            print("Invalid input. Please enter a number.")

# --- Shape menu dictionary ---
shapes = {
    "1": {
        "name": "Rectangle",
        "area": lambda: rectangle_area(
            get_number("Enter length: "),
            get_number("Enter width: ")
        ),
        "perimeter": lambda: rectangle_perimeter(
            get_number("Enter length again: "),
            get_number("Enter width again: ")
        )
    },
    "2": {
        "name": "Circle",
        "area": lambda: circle_area(get_number("Enter radius: ")),
        "perimeter": lambda: circle_perimeter(get_number("Enter radius again: "))
    },
    "3": {
        "name": "Square",
        "area": lambda: square_area(get_number("Enter side length: ")),
        "perimeter": lambda: square_perimeter(get_number("Enter side length again: "))
    },
    "4": {
        "name": "Triangle",
        "area": lambda: triangle_area(
            get_number("Enter base: "),
            get_number("Enter height: ")
        ),
        "perimeter": lambda: triangle_perimeter(
            get_number("Enter side a: "),
            get_number("Enter side b: "),
            get_number("Enter side c: ")
        )
    },
    "5": {
        "name": "Parallelogram",
        "area": lambda: parallelogram_area(
            get_number("Enter base: "),
            get_number("Enter height: ")
        ),
        "perimeter": lambda: parallelogram_perimeter(
            get_number("Enter side a: "),
            get_number("Enter side b: ")
        )
    }
}

# --- Main loop ---
if __name__ == "__main__":
    print("Area & Perimeter Calculator (Dictionary Version)")

    while True:
        print("\nChoose shape:")
        print("1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit")
        choice = input("Enter choice (1-6): ")

        if choice == "6":
            print("Exiting program. Goodbye!")
            break
        elif choice in shapes:
            shape = shapes[choice]
            area = shape["area"]()
            perimeter = shape["perimeter"]()
            print(f"\n{shape['name']} Area = {area:.2f}")
            print(f"{shape['name']} Perimeter = {perimeter:.2f}")
        else:
            print("Invalid choice. Please select 1-6.")
# Out:
# Area & Perimeter Calculator (Dictionary Version)
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 1
# Enter length: 5
# Enter width: 3
# Enter length again: 5
# Enter width again: 3
#
# Rectangle Area = 15.00
# Rectangle Perimeter = 16.00
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 2
# Enter radius: 4
# Enter radius again: 4
#
# Circle Area = 50.27
# Circle Perimeter = 25.13
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 3
# Enter side length: 6
# Enter side length again: 6
#
# Square Area = 36.00
# Square Perimeter = 24.00
#
# Choose shape:
# 1) Rectangle  2) Circle  3) Square  4) Triangle  5) Parallelogram  6) Exit
# Enter choice (1-6): 4
# Enter base: 3
# Enter height: 4
# Enter side a: 3
# Enter side b: 4
# Enter side c: 5
#
# Triangle Area = 6.00
# ...

# %% [markdown]
# # **เมื่อเปรียบเทียบ Sprint 3 กับ Dictionary Version จะเห็นว่ามีการ เปลี่ยนแปลงและปรับปรุงใหญ่ ๆ ดังนี้:**
#
# 1. การจัดโครงสร้างโค้ด
#
# Sprint 3: ใช้ if-elif แบบยาว ๆ สำหรับแต่ละรูปทรง
#
# Dictionary Version: เปลี่ยนมาใช้ dictionary (shapes) เก็บข้อมูลของแต่ละรูปทรง
#
# แต่ละ key เป็นเลขตัวเลือก "1", "2", …
#
# แต่ละ value เป็น dictionary ที่เก็บ:
#
# "name" → ชื่อรูปทรง
#
# "area" → ฟังก์ชัน lambda คำนวณพื้นที่
#
# "perimeter" → ฟังก์ชัน lambda คำนวณเส้นรอบรูป
#
# ผลลัพธ์: โค้ดสั้นลง ลดซ้ำซ้อน ใช้ loop เดียวสำหรับทุก shape
#
#
# 2. ฟังก์ชัน geometry
#
# ฟังก์ชันทั้งหมดเหมือน Sprint 3 (rectangle_area, circle_area, square_area, triangle_area, parallelogram_area และ perimeter)
#
# ไม่มีการเปลี่ยนแปลงที่ logic ของการคำนวณ แต่ Dictionary Version เรียกใช้ผ่าน lambda
#
#
# 3. การรับ input
#
# Sprint 3: รับค่า input ในแต่ละ if-elif ด้วย get_number()
#
# Dictionary Version: ยังคงใช้ get_number() แต่เรียกจาก lambda ใน dictionary
#
# จุดต่าง: lambda ทำให้สามารถรับ input แยกกันสำหรับ area และ perimeter
#
# เช่น rectangle_area() กับ rectangle_perimeter() จะขอ input แยกกัน (Enter length:, Enter length again:)
#
# ลดความซ้ำซ้อนของโค้ด loop เมนู
#
#
# 4. เมนูและ main loop
#
# Sprint 3: มี if-elif 1–6
#
# Dictionary Version: loop menu ใช้
#
# elif choice in shapes:
#     shape = shapes[choice]
#     area = shape["area"]()
#     perimeter = shape["perimeter"]()
#     print(...)
#
#
# ผลลัพธ์: เพิ่ม scalability ง่ายต่อการเพิ่ม shape ใหม่ แค่เพิ่ม key/value ใน dictionary ไม่ต้องเขียน if-elif ใหม่
#
#
# 5. ชื่อโปรแกรม
#
# เปลี่ยนจาก "Area & Perimeter Calculator (Sprint 3)" → "Area & Perimeter Calculator (Dictionary Version)"
#
#
# 6. Exit
#
# ยังคงเป็น choice 6 เช่นเดิม
#
# Dictionary Version แยก logic if choice == "6": แทนที่จะรวมใน if-elif
#
#
# 7. จุดเด่นอื่น ๆ
#
# ลดโค้ดซ้ำ เช่น ไม่ต้องเขียน print สำหรับแต่ละ shape ซ้ำหลายบรรทัด
#
# ใช้ lambda functions ให้ฟังก์ชันคำนวณและ input ถูกเก็บใน dictionary ทำให้ main loop สั้นและชัดเจน
